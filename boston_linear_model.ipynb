# %%
from sklearn.datasets import load_boston
boston=load_boston()
print("Description of boston dataset:\n",boston.DESCR)

# %%
from sklearn.datasets import load_boston
import pandas as pd
boston_df=pd.DataFrame(boston.data,columns=boston.feature_names)
boston_df['TARGET']=boston.target
boston_df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.datasets import load_boston
#       2 import pandas as pd
#       3 boston_df=pd.DataFrame(boston.data,columns=boston.feature_names)
#
# File ~\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:161, in __getattr__(name)
#     110 if name == "load_boston":
#     111     msg = textwrap.dedent(
#     112         """
#     113         `load_boston` has been removed from scikit-learn since version 1.2.
#    (...)
#     159         """
#     160     )
# --> 161     raise ImportError(msg)
#     162 try:
#     163     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(boston.data,boston.target,
                                               random_state=0)

#OLS linear Regression
lr=LinearRegression()
lr.fit(X_train,y_train)

#learned parameters of the model
print("Slope: ",lr.coef_)
print("Y-intercept: ",lr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train,X_test,y_train,y_test=train_test_split(boston.data,boston.target,
#       4                                                random_state=0)
#       6 #OLS linear Regression
#       7 lr=LinearRegression()
#
# NameError: name 'boston' is not defined

# %%
#Accuracy of the model
print("Accuracy of the training set: ",lr.score(X_train,y_train))
print("Accuracy of the testing set: ",lr.score(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Accuracy of the model
# ----> 2 print("Accuracy of the training set: ",lr.score(X_train,y_train))
#       3 print("Accuracy of the testing set: ",lr.score(X_test,y_test))
#
# NameError: name 'lr' is not defined

# %%
import mglearn
import warnings
warnings.filterwarnings("ignore")
X,y=mglearn.datasets.load_extended_boston()

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

#OLS linear Regression
lr=LinearRegression()
lr.fit(X_train,y_train)

#Accuracy of the model
print("Accuracy of the training set: ",lr.score(X_train,y_train))
print("Accuracy of the testing set: ",lr.score(X_test,y_test))
# Out:
# Accuracy of the training set:  0.9520519609032729
# Accuracy of the testing set:  0.6074721959665845

# %%
import mglearn
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split

# Load the Extended Boston Housing dataset
X, y = mglearn.datasets.load_extended_boston()

# %%
# Load the extended dataset
X, y = mglearn.datasets.load_extended_boston()

print("Extended Boston Housing Dataset Loaded")
print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1])
# Out:
# Extended Boston Housing Dataset Loaded
# Number of samples: 506
# Number of features: 104

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

print("Linear Regression:")
print("Training set accuracy:", lr.score(X_train, y_train))
print("Testing set accuracy:", lr.score(X_test, y_test))
# Out:
# Linear Regression:
# Training set accuracy: 0.9520519609032729
# Testing set accuracy: 0.6074721959665845

# %%
ridge = Ridge(alpha=1)
ridge.fit(X_train, y_train)

print("\nRidge Regression (alpha=1):")
print("Training set accuracy:", ridge.score(X_train, y_train))
print("Testing set accuracy:", ridge.score(X_test, y_test))
# Out:
# Ridge Regression (alpha=1):
# Training set accuracy: 0.8857966585170941
# Testing set accuracy: 0.7527683481744755

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Corrected dataset
data = {
    'TV': [230.1, 44.5, 17.2, 151.5, 180.8],
    'Radio': [37.8, 39.3, 45.9, 41.3, 10.8],
    'Newspaper': [69.2, 45.1, 69.3, 58.5, 58.4],
    'Sales': [22.1, 10.4, 9.3, 18.5, 12.9]
}

df = pd.DataFrame(data)

# Features and target
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

# Model
model = LinearRegression()
model.fit(X, y)

# Predictions and accuracy
y_pred = model.predict(X)
accuracy = r2_score(y, y_pred)

print("Model Accuracy (R² score):", accuracy)
#Predict Sales for New Data


# New unseen data
new_data = np.array([[165.5, 20.0, 35.4]])

# Predict
predicted_sales = model.predict(new_data)
print("Predicted Sales:", predicted_sales[0])
# Out:
# Model Accuracy (R² score): 0.9976528964645683
# Predicted Sales: 14.903108568980505
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

x = np.array([[12, 5, 2, 4],
              [7, 6, 8, 8],
              [1, 6, 7, 7]])

# array([[12, 5, 2],
#        [7, 6, 8]])
first_slice = x[:2, :3]
print("First Slice:\n", first_slice)


# array([[12, 2],
#        [7, 8],
#        [1, 7]])
second_slice = x[:, [0, 2]]
print("Second Slice:\n", second_slice)
print("3rd slice:\n", x[::-1,::-1])
# Out:
# First Slice:
#  [[12  5  2]
#  [ 7  6  8]]
# Second Slice:
#  [[12  2]
#  [ 7  8]
#  [ 1  7]]
# 3rd slice:
#  [[ 7  7  6  1]
#  [ 8  8  6  7]
#  [ 4  2  5 12]]

# %% [markdown]
# * Regularization to avoid overfitting, problem with ols --overfitting
# * coef  used to make predictions
# Ridge L2() :

# %% [markdown]
# import mglearn
# import pandas as pd
# from sklearn.linear_model import LinearRegression, Ridge
# from sklearn.model_selection import train_test_split
#
# # Load the Extended Boston Housing dataset
# X, y = mglearn.datasets.load_extended_boston()
# from sklearn.linear_model import Ridge
# X_train, X_train, y_train, y_test= train_test_split()
#
# model= Ridge()
# model.fit(X_train, y_train)
#
#
# print("Training set accuracy:", model.score(X_train, y_train))
# print("Testing set accuracy:", model .score(X_test, y_test))

# %%
#parameters to control

# %%
# %pip install mglearn
# Out:
# ...
#
# ...

# %%
import mglearn
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split

# Load the Extended Boston Housing dataset
X, y = mglearn.datasets.load_extended_boston()
from sklearn.linear_model import Ridge
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

model= Ridge()
model.fit(X_train, y_train) 


print("Training set accuracy:", model.score(X_train, y_train))
print("Testing set accuracy:", model .score(X_test, y_test))
# Out:
# Training set accuracy: 0.8857966585170941
# Testing set accuracy: 0.7527683481744755

# %%
ridge = Ridge(alpha=1)
ridge.fit(X_train, y_train)

print("\nRidge Regression (alpha=1):")
print("Training set accuracy:", ridge.score(X_train, y_train))
print("Testing set accuracy:", ridge.score(X_test, y_test))
# Out:
# Ridge Regression (alpha=1):
# Training set accuracy: 0.8857966585170941
# Testing set accuracy: 0.7527683481744755

# %%
# analyze effect of regulazition ,check the coefficient / plot them 

ridge.coef_
# Out:
# array([-1.41368408e+00, -1.55661895e+00, -1.46543409e+00, -1.26616071e-01,
#        -7.91193605e-02,  8.33161023e+00,  2.54975060e-01, -4.94145701e+00,
#         3.89862268e+00, -1.05866058e+00, -1.58433734e+00,  1.05103856e+00,
#        -4.01220799e+00,  3.33720475e-01,  3.64725471e-03, -8.49295793e-01,
#         7.44989267e-01, -1.43106836e+00, -1.62981017e+00, -1.40486294e+00,
#        -4.47314366e-02, -1.74619880e+00, -1.46715888e+00, -1.33237111e+00,
#        -1.69154625e+00, -5.06179637e-01,  2.62197591e+00, -2.09210002e+00,
#         1.95074661e-01, -2.75469422e-01,  5.11308202e+00, -1.67083739e+00,
#        -9.81863179e-02,  6.34477127e-01, -6.10008281e-01,  4.01805897e-02,
#        -1.27661999e+00, -2.91349679e+00,  3.39544035e+00,  7.91904036e-01,
#         1.35260232e+00, -4.03661265e+00,  2.32361734e+00, -3.36712926e+00,
#         1.81279204e+00,  3.01566897e+00, -1.89452070e+00, -2.50844073e-01,
# ...

# %%
model.coef_
# Out:
# array([-1.41368408e+00, -1.55661895e+00, -1.46543409e+00, -1.26616071e-01,
#        -7.91193605e-02,  8.33161023e+00,  2.54975060e-01, -4.94145701e+00,
#         3.89862268e+00, -1.05866058e+00, -1.58433734e+00,  1.05103856e+00,
#        -4.01220799e+00,  3.33720475e-01,  3.64725471e-03, -8.49295793e-01,
#         7.44989267e-01, -1.43106836e+00, -1.62981017e+00, -1.40486294e+00,
#        -4.47314366e-02, -1.74619880e+00, -1.46715888e+00, -1.33237111e+00,
#        -1.69154625e+00, -5.06179637e-01,  2.62197591e+00, -2.09210002e+00,
#         1.95074661e-01, -2.75469422e-01,  5.11308202e+00, -1.67083739e+00,
#        -9.81863179e-02,  6.34477127e-01, -6.10008281e-01,  4.01805897e-02,
#        -1.27661999e+00, -2.91349679e+00,  3.39544035e+00,  7.91904036e-01,
#         1.35260232e+00, -4.03661265e+00,  2.32361734e+00, -3.36712926e+00,
#         1.81279204e+00,  3.01566897e+00, -1.89452070e+00, -2.50844073e-01,
# ...

# %%
#let's plot  for analyzation 
import matplotlib.pyplot as plt 
plt.plot(ridge.coef_, "s", label= 'alpha=1')
#plt.plot(ridge.coef_, "o", label= 'alpha=10')
plt.plot(model.coef_, "v", label= 'alpha=1')
plt.legend()
plt.ylim 
plt.plot(model.coef_, "v", label= 'alpha=1')
plt.hlines(0,0, len(ridge.coef_),color= 'black')
#each of the feature has an inference

# %%
from sklearn.linear_model import Lasso
import numpy as np 

lasso001=  Lasso(alpha=0.01, max_iter= 100000).fit(X_train, y_train) 

lasso= Lasso().fit(X_train,y_train) 

print ("Accuracy of the training set: ", lasso001.score(X_train,y_train))
print ("Accuracy of the testing set: ", lasso001.score(X_test,y_test)) 

print( "Number of features used: ", np.sum(lasso001.coef_!= 0))
# Out:
# Accuracy of the training set:  0.8962226511086497
# Accuracy of the testing set:  0.7656571174549983
# Number of features used:  33
